# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#path
#file location+file name+extension
path=r"C:\Users\manch\Downloads\Visadataset - Visadataset.csv"

# %%
pd.read_csv(path)
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
#data set name=bank
path=r"C:\Users\manch\Downloads\bank - bank.csv"
pd.read_csv(path,sep=';')
# Out:
#      age,job,marital,education,default,balance,housing,loan,contact,day,month,duration,campaign,pdays,previous,poutcome,y
# 0     30,unemployed,married,primary,no,1787,no,no,ce...
# 1     33,services,married,secondary,no,4789,yes,yes,...
# 2     35,management,single,tertiary,no,1350,yes,no,c...
# 3     30,management,married,tertiary,no,1476,yes,yes...
# 4     59,blue-collar,married,secondary,no,0,yes,no,u...
# ...                                                 ...
# 4516  33,services,married,secondary,no,-333,yes,no,c...
# 4517  57,self-employed,married,tertiary,yes,-3313,ye...
# 4518  57,technician,married,secondary,no,295,no,no,c...
# 4519  28,blue-collar,married,secondary,no,1137,no,no...
# 4520  44,entrepreneur,single,tertiary,no,1136,yes,ye...
#
# [4521 rows x 1 columns]

# %%
#data set name=bank
path=r"C:\Users\manch\Downloads\bank - bank.csv"
pd.read_csv(path)
# Out:
#       age            job  marital  education default  balance housing loan  \
# 0      30     unemployed  married    primary      no     1787      no   no
# 1      33       services  married  secondary      no     4789     yes  yes
# 2      35     management   single   tertiary      no     1350     yes   no
# 3      30     management  married   tertiary      no     1476     yes  yes
# 4      59    blue-collar  married  secondary      no        0     yes   no
# ...   ...            ...      ...        ...     ...      ...     ...  ...
# 4516   33       services  married  secondary      no     -333     yes   no
# 4517   57  self-employed  married   tertiary     yes    -3313     yes  yes
# 4518   57     technician  married  secondary      no      295      no   no
# 4519   28    blue-collar  married  secondary      no     1137      no   no
# 4520   44   entrepreneur   single   tertiary      no     1136     yes  yes
#
# ...

# %% [markdown]
# **create data frames using list**

# %%
name=['Ramesh','Suresh','sathish']
age=[30,35,40]
name,age
# Out:
# (['Ramesh', 'Suresh', 'sathish'], [30, 35, 40])

# %%
pd.DataFrame() #make the data frame
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
pd.DataFrame(zip(name,age))
# Out:
#          0   1
# 0   Ramesh  30
# 1   Suresh  35
# 2  sathish  40

# %%
#provide columns
data=zip(name,age)
pd.DataFrame(data,columns=['Name','Age'])
# Out:
#       Name  Age
# 0   Ramesh   30
# 1   Suresh   35
# 2  sathish   40

# %% [markdown]
# $provide index$

# %%
data=zip(name,age)
cols=['Name','Age']
ind=['A','B','C']
pd.DataFrame(data,
             columns=cols,
            index=ind)
# Out:
#       Name  Age
# A   Ramesh   30
# B   Suresh   35
# C  sathish   40

# %% [markdown]
# $Add new column$

# %%
name=['Ramesh','Suresh','sathish']
age=[30,35,40]
data=zip(name,age)
cols=['Name','Age']
ind=['A','B','C']
df=pd.DataFrame(data,columns=cols,index=ind)
df
# Out:
#       Name  Age
# A   Ramesh   30
# B   Suresh   35
# C  sathish   40

# %%
city_names=['Hyderabad','Bangalore','Chennai']
df['city']=city_names
df
# Out:
#       Name  Age       city
# A   Ramesh   30  Hyderabad
# B   Suresh   35  Bangalore
# C  sathish   40    Chennai

# %% [markdown]
# **update  the  existing  column**

# %%
df['Name']=['Swamy','Asif','Sathwik']
df
# Out:
#       Name  Age       city
# A    Swamy   30  Hyderabad
# B     Asif   35  Bangalore
# C  Sathwik   40    Chennai

# %% [markdown]
# step -7
#
# Drop the  column

# %%
df.drop('city',
       axis=1,
       inplace=True)
df
# Out:
#       Name  Age
# A    Swamy   30
# B     Asif   35
# C  Sathwik   40

# %%
df.drop('C',
       axis=0,
       inplace=True)
df
# Out:
#      Name  Age       city
# A  Ramesh   30  Hyderabad
# B  Suresh   35  Bangalore

# %%
name=['Ramesh','Suresh','sathish']
age=[30,35,40]
data=zip(name,age)
cols=['Name','Age']
ind=['A','B','C']
df=pd.DataFrame(data,columns=cols,index=ind)
city_names=['Hyderabad','Bangalore','Chennai']
df['city']=city_names
df.drop('C',
       axis=0,
       inplace=True)
df
# Out:
#      Name  Age       city
# A  Ramesh   30  Hyderabad
# B  Suresh   35  Bangalore

# %% [markdown]
# Save the data frame

# %%
df.to_csv("output.csv")

# %%
pd.read_csv("output.csv")
# Out:
#   Unnamed: 0    Name  Age       city
# 0          A  Ramesh   30  Hyderabad
# 1          B  Suresh   35  Bangalore

# %%
df.to_csv("output.csv",index=False)
df
# Out:
#      Name  Age       city
# A  Ramesh   30  Hyderabad
# B  Suresh   35  Bangalore

# %%
pd.read_csv("output.csv")
# Out:
#      Name  Age       city
# 0  Ramesh   30  Hyderabad
# 1  Suresh   35  Bangalore

# %% [markdown]
# create dataframes using dictionary

# %%
d1={"NAME":['Ramesh','suresh','Sathish'],
   "AGE":[30,35,40]}
pd.DataFrame(d1)
# Out:
#       NAME  AGE
# 0   Ramesh   30
# 1   suresh   35
# 2  Sathish   40

# %%
pwd
# Out:
# 'C:\\Users\\manch\\OneDrive\\Documents\\Desktop\\naresh IT\\Data science\\EDA'
